# %%
###  Reset Index , set index ,indexing and slicing of index object get_loc , is_unique , create index object from scratch

# %%
import pandas as pd

# %%
#  set column as an index
movie=pd.read_csv("tmdb_5000_movies.csv" ,index_col="original_title")
movie
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
# ...                                             ...
# El Mariachi                                  220000
# Newlyweds                                      9000
# Signed, Sealed, Delivered                         0
# Shanghai Calling                                  0
# My Date with Drew                                 0
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
#  reset index
movie.reset_index()
# Out:
#                                 original_title     budget  \
# 0                                       Avatar  237000000
# 1     Pirates of the Caribbean: At World's End  300000000
# 2                                      Spectre  245000000
# 3                        The Dark Knight Rises  250000000
# 4                                  John Carter  260000000
# ...                                        ...        ...
# 4798                               El Mariachi     220000
# 4799                                 Newlyweds       9000
# 4800                 Signed, Sealed, Delivered          0
# 4801                          Shanghai Calling          0
# 4802                         My Date with Drew          0
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
movie
#  here index not reset
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
# ...                                             ...
# El Mariachi                                  220000
# Newlyweds                                      9000
# Signed, Sealed, Delivered                         0
# Shanghai Calling                                  0
# My Date with Drew                                 0
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
movie.reset_index(inplace=True)
#  here now index is reset in original dataframe
movie
# Out:
#       index                            original_title     budget  \
# 0         0                                    Avatar  237000000
# 1         1  Pirates of the Caribbean: At World's End  300000000
# 2         2                                   Spectre  245000000
# 3         3                     The Dark Knight Rises  250000000
# 4         4                               John Carter  260000000
# ...     ...                                       ...        ...
# 4798   4798                               El Mariachi     220000
# 4799   4799                                 Newlyweds       9000
# 4800   4800                 Signed, Sealed, Delivered          0
# 4801   4801                          Shanghai Calling          0
# 4802   4802                         My Date with Drew          0
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
#  replace value of index
movie.set_index("id",inplace=True)
movie
# Out:
#         index                            original_title     budget  \
# id
# 19995       0                                    Avatar  237000000
# 285         1  Pirates of the Caribbean: At World's End  300000000
# 206647      2                                   Spectre  245000000
# 49026       3                     The Dark Knight Rises  250000000
# 49529       4                               John Carter  260000000
# ...       ...                                       ...        ...
# 9367     4798                               El Mariachi     220000
# 72766    4799                                 Newlyweds       9000
# 231617   4800                 Signed, Sealed, Delivered          0
# 126186   4801                          Shanghai Calling          0
# 25975    4802                         My Date with Drew          0
#
#                                                    genres  \
# id
# 19995   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
#  both index and columns are index type

# %%
movie.index
# Out:
# Int64Index([ 19995,    285, 206647,  49026,  49529,    559,  38757,  99861,
#                767, 209112,
#             ...
#             182291, 286939, 124606,  14337,  67238,   9367,  72766, 231617,
#             126186,  25975],
#            dtype='int64', name='id', length=4803)

# %%
movie.columns
# Out:
# Index(['index', 'original_title', 'budget', 'genres', 'keywords',
#        'original_language', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
type(movie.index)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
type(movie.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
#  indexing and slicing of index and columns

# %%
movie.index[0]
# Out:
# 19995

# %%
movie.columns[2]
# Out:
# 'budget'

# %%
movie.index[8:12]
# Out:
# Int64Index([767, 209112, 1452, 10764], dtype='int64', name='id')

# %%
movie.columns[-2:]
# Out:
# Index(['vote_average', 'vote_count'], dtype='object')

# %%
#  get location of values

# %%
movie.index.get_loc(49026)
# Out:
# 3

# %%
movie.columns.get_loc('original_title')
# Out:
# 1

# %%
#  is there all values are unique

# %%
movie.index.is_unique
# Out:
# True

# %%
movie.columns.is_unique
# Out:
# True

# %%
#  create index object

# we can use all method on this too

# %%
xyz=pd.Index(["A","B","c"])
xyz
# Out:
# Index(['A', 'B', 'c'], dtype='object')

# %%
xyz.is_unique
# Out:
# True

# %%
ser=pd.Series([1,2,3],index=xyz)

# %%
ser
# Out:
# A    1
# B    2
# c    3
# dtype: int64
