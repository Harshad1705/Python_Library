# %%
import pandas as pd

# %%
df=pd.read_csv("Suicide.csv")
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df[df.year >= 2014]
# Out:
#                    country  year     sex          age  suicides_no  \
# 564    Antigua and Barbuda  2014  female  15-24 years            0
# 565    Antigua and Barbuda  2014  female  25-34 years            0
# 566    Antigua and Barbuda  2014  female  35-54 years            0
# 567    Antigua and Barbuda  2014  female   5-14 years            0
# 568    Antigua and Barbuda  2014  female  55-74 years            0
# ...                    ...   ...     ...          ...          ...
# 27815           Uzbekistan  2014  female  35-54 years          107
# 27816           Uzbekistan  2014  female    75+ years            9
# 27817           Uzbekistan  2014    male   5-14 years           60
# 27818           Uzbekistan  2014  female   5-14 years           44
# 27819           Uzbekistan  2014  female  55-74 years           21
#
#        population  suicides/100k pop             country-year  HDI for year  \
# 564          8537               0.00  Antigua and Barbuda2014         0.783
# ...

# %%
df[df.year.between(2000,2010)]
# Out:
#           country  year     sex          age  suicides_no  population  \
# 132       Albania  2000    male  25-34 years           17      232000
# 133       Albania  2000    male  55-74 years           10      177400
# 134       Albania  2000  female    75+ years            2       37800
# 135       Albania  2000    male    75+ years            1       24900
# 136       Albania  2000  female  15-24 years            6      263900
# ...           ...   ...     ...          ...          ...         ...
# 27767  Uzbekistan  2010  female  35-54 years          101     3339076
# 27768  Uzbekistan  2010    male   5-14 years           48     2751752
# 27769  Uzbekistan  2010  female    75+ years            5      322899
# 27770  Uzbekistan  2010  female  55-74 years           16     1161422
# 27771  Uzbekistan  2010  female   5-14 years           30     2627344
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df[df.year.isin([2005,2010])]
# Out:
#           country  year     sex          age  suicides_no  population  \
# 192       Albania  2005  female  15-24 years            0      281922
# 193       Albania  2005  female  25-34 years            0      190745
# 194       Albania  2005  female  35-54 years            0      386513
# 195       Albania  2005  female   5-14 years            0      276559
# 196       Albania  2005  female  55-74 years            0      210998
# ...           ...   ...     ...          ...          ...         ...
# 27767  Uzbekistan  2010  female  35-54 years          101     3339076
# 27768  Uzbekistan  2010    male   5-14 years           48     2751752
# 27769  Uzbekistan  2010  female    75+ years            5      322899
# 27770  Uzbekistan  2010  female  55-74 years           16     1161422
# 27771  Uzbekistan  2010  female   5-14 years           30     2627344
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# 2010 - 2014
#  males & FEMALES , SWITZERLAND

# %%
mask1=df.year.between(2010,2014)
mask2=df.sex=="male"
mask3=df.sex=="female"
mask4=df.country=="Switzerland"

# %%
male=df.loc[mask1 & mask2 & mask4 , ["country","sex","age","suicides_no"]]
male
# Out:
#            country   sex          age  suicides_no
# 24906  Switzerland  male    75+ years          114
# 24907  Switzerland  male  55-74 years          220
# 24908  Switzerland  male  35-54 years          267
# 24909  Switzerland  male  25-34 years           74
# 24911  Switzerland  male  15-24 years           47
# 24916  Switzerland  male   5-14 years            2
# 24918  Switzerland  male    75+ years          125
# 24919  Switzerland  male  55-74 years          221
# 24920  Switzerland  male  35-54 years          261
# 24921  Switzerland  male  25-34 years           81
# 24922  Switzerland  male  15-24 years           67
# 24928  Switzerland  male   5-14 years            2
# 24930  Switzerland  male    75+ years          129
# 24931  Switzerland  male  55-74 years          238
# 24932  Switzerland  male  35-54 years          251
# 24933  Switzerland  male  15-24 years           65
# 24934  Switzerland  male  25-34 years           66
# ...

# %%
male.sum().suicides_no
# Out:
# 3775

# %%
female=df.loc[mask1 & mask3 & mask4 , ["country","sex","age","suicides_no"]]
female
# Out:
#            country     sex          age  suicides_no
# 24910  Switzerland  female  55-74 years           96
# 24912  Switzerland  female    75+ years           36
# 24913  Switzerland  female  35-54 years          103
# 24914  Switzerland  female  25-34 years           32
# 24915  Switzerland  female  15-24 years           15
# 24917  Switzerland  female   5-14 years            0
# 24923  Switzerland  female    75+ years           44
# 24924  Switzerland  female  55-74 years           94
# 24925  Switzerland  female  35-54 years           98
# 24926  Switzerland  female  25-34 years           25
# 24927  Switzerland  female  15-24 years           15
# 24929  Switzerland  female   5-14 years            1
# 24935  Switzerland  female  55-74 years          102
# 24936  Switzerland  female    75+ years           41
# 24937  Switzerland  female  35-54 years          104
# 24938  Switzerland  female  25-34 years           29
# 24939  Switzerland  female  15-24 years           10
# ...

# %%
female.sum().suicides_no
# Out:
# 1406
